# %% [markdown]
# # 📚 Create database
# Creat database from cvs file containing data gathered from the [South African Air Quality Information System](https://saaqis.environment.gov.za/)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Twist2
# Out:
# /content/gdrive/MyDrive/Twist2

# %% [markdown]
# ## CSV files in drive:
# Each site has two files associated with it

# %%
# !ls
# Out:
# 0_Create_Database.ipynb			 North_West_University_Vaal_campus.csv
# 1_EDA.ipynb				 Sharpeville-2.csv
# AJ_Jacobs-2.csv				 Sharpeville.csv
# AJ_Jacobs.csv				 Site_info.csv
# Bongani_Mabaso_Eco_Park-2.csv		 Vanderbijlpark-NAQI-2.csv
# Bongani_Mabaso_Eco_Park.csv		 Vanderbijlpark-NAQI.csv
# Leitrim-2.csv				 Zamdela-NAQI-2.csv
# Leitrim.csv				 Zamdela-NAQI.csv
# North_West_University_Vaal_campus-2.csv

# %%
# !pip install pyodbc
# Out:
# ...
#      |████████████████████████████████| 280 kB 8.2 MB/s
# ...
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp37-cp37m-linux_x86_64.whl size=287364 sha256=38dc6847ec52791ee7b60ce3642e92830afbf8ba1e1f99394832391af660a0e1
#   Stored in directory: /root/.cache/pip/wheels/2e/9c/da/8652fd42e0f662015554f00a9e96fe4f438dfd1ef59787879e
# Successfully built pyodbc
# ...

# %%
import sqlite3
import csv

# %% [markdown]
# ## Create and connect to database

# %%
con = sqlite3.connect("air_pollution_database.db")
cur = con.cursor()

# %% [markdown]
# ## Create table for site: AJ Jacobs

# %%
cur.execute('''CREATE TABLE AJ_Jacobs (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float, CO float, PM2_5 float, PM10 float, 
  Amb_Wspeed float, Amb_WDirection float)''')

con.commit()

data_file = open("AJ_Jacobs.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO AJ_Jacobs VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("AJ_Jacobs-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO AJ_Jacobs VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site: Bongani Mabaso Eco Park

# %%
cur.execute('''CREATE TABLE Bongani_Mabaso_Eco_Park (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float, O3 float, PM2_5 float, PM10 float, Amb_Wspeed float, Amb_WDirection float, Temperature float, Rain float)''')

con.commit()

data_file = open("Bongani_Mabaso_Eco_Park.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Bongani_Mabaso_Eco_Park VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("Bongani_Mabaso_Eco_Park-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Bongani_Mabaso_Eco_Park VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site: Leitrim

# %%
cur.execute('''CREATE TABLE Leitrim (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float, CO float, PM2_5 float, PM10 float, 
  Amb_Wspeed float, Amb_WDirection float, Temperature_float)''')

con.commit()

data_file = open("Leitrim.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Leitrim VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("Leitrim-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Leitrim VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site: North West University Vaal campus

# %%
cur.execute('''CREATE TABLE North_West_University_Vaal_campus (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float, O3 float, CO float, PM2_5 float, PM10 float, 
  Amb_Wspeed float, Amb_WDirection float, Temperature float, Amb_RelHum float, 
  Solar_Radiation float, Amb_Pressure float, Rain float, Shelter_Line_V float, 
  Shelter_IntTemp float)''')

con.commit()

data_file = open("North_West_University_Vaal_campus.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO North_West_University_Vaal_campus VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("North_West_University_Vaal_campus-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO North_West_University_Vaal_campus VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site: Sharpeville

# %%
cur.execute('''CREATE TABLE Sharpeville (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float, O3 float, CO float, PM2_5 float, 
  PM10 float, Black_Carbon float, Benzene float, Toluene float, O_xylene float, 
  P_xylene float, Ethyl_Benzene float, Amb_Wspeed float, Amb_WDirection float, 
  Temperature float, Amb_RelHum float, Solar_Radiation float, Amb_Pressure float, 
  Rain float, RH float, Shelter_IntTemp float)''')

con.commit()

data_file = open("Sharpeville.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Sharpeville VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("Sharpeville-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Sharpeville VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site:  Vanderbijlpark NAQI

# %%
cur.execute('''CREATE TABLE Vanderbijlpark_NAQI (time int, day int, month int, year int, 
  SO2 float, O3 float, PM2_5 float, PM10 float, PM_Coarse float, Toluene float, 
  Amb_Wspeed float, Amb_WDirection float, Temperature float, Amb_RelHum float, 
  Solar_Radiation float, Amb_Pressure float, Rain float, Shelter_UPS_V float, 
  Shelter_Line_V float, Shelter_IntTemp float)''')

con.commit()

data_file = open("Vanderbijlpark-NAQI.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Vanderbijlpark_NAQI VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("Vanderbijlpark-NAQI-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Vanderbijlpark_NAQI VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %% [markdown]
# ## Create table for site: Zamdela NAQI

# %%
cur.execute('''CREATE TABLE Zamdela_NAQI (time int, day int, month int, year int, 
  SO2 float, NO2 float, NO float, NOx float,O3 float, CO float, PM2_5 float, 
  PM10 float, Black_Carbon float, Benzene float, Toluene float, O_xylene float, 
  P_xylene float, Ethyl_Benzene float, H2S float, Amb_Wspeed float, 
  Amb_WDirection float, Temperature float, Amb_RelHum float, Solar_Radiation float, 
  Amb_Pressure float, Rain float, Shelter_IntTemp float)''')

con.commit()

data_file = open("Zamdela-NAQI.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Zamdela_NAQI VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

data_file = open("Zamdela-NAQI-2.csv")
rows = csv.reader(data_file)
cur.executemany("INSERT INTO Zamdela_NAQI VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", rows)

con.commit()

# %%
con.close()

# %% [markdown]
# ## List tables in database

# %%
con = sqlite3.connect("air_pollution_database.db")
cur = con.cursor()

sql_query = """SELECT name FROM sqlite_master  
  WHERE type='table';"""
cursor = con.cursor()
cursor.execute(sql_query)
print(cursor.fetchall())

con.close()
# Out:
# [('AJ_Jacobs',), ('Bongani_Mabaso_Eco_Park',), ('Leitrim',), ('North_West_University_Vaal_campus',), ('Sharpeville',), ('Vanderbijlpark_NAQI',), ('Zamdela_NAQI',)]
